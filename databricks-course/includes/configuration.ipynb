# %%
bronze_folder_path = "abfss://bronze@moviehistory22.dfs.core.windows.net"
silver_folder_path = "abfss://silver@moviehistory22.dfs.core.windows.net"
gold_folder_path = "abfss://gold@moviehistory22.dfs.core.windows.net"
