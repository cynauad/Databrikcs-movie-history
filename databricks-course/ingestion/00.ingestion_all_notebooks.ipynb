# %% [markdown]
# ### Este notebook ejecutara los todos los notebooks creados.
#
# - No es la mejor forma de hacerlo en Azure. Pero se explica igual.
# - Tiene algunos problemas
# - Para esto esta Azure Data Factory (ADF). Se explica luego

# %%
dbutils.notebook.help()

# %%
file_date = "2024-12-30"

# %%
v_result = dbutils.notebook.run("01. ingestion_file_movie", 0, {"p_environment": "production", "p_file_date":file_date})   
# notebook, tiempo en seg, variable.

# %%
v_result

# %%
v_result = dbutils.notebook.run("02. ingestion_file_language", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("03. ingestion_file_genre", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("04. ingesta_file_country", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("05. ingesta_file_person", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("06. ingesta_file_movie_genre", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("07. ingesta_file_movie_cast", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("08. ingesta_file_language_role", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("09. ingestion_folder_production_company", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("10. ingestion_folder_movie_company", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("11. ingestion_folder_movie_languages", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result

# %%
v_result = dbutils.notebook.run("12. ingestion_folder_production_country", 0, {"p_environment": "production", "p_file_date":file_date})

# %%
v_result
