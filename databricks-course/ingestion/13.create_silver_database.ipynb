-- %% [markdown]
-- Creamos un schema en el contenedor Silver. Van a ser administradas por DB, pero podemos darle una ubicacion que definamos.

-- %%
CREATE SCHEMA IF NOT EXISTS movie_silver
MANAGED LOCATION "abfss://silver@moviehistory22.dfs.core.windows.net";

-- %%
DESC DATABASE movie_silver

-- %%
-- En todas las notebook creamos un archivo... ahora queremos crear las tablas.
-- Entonces vamos a modificar la escritura de las notebooks que creamos para que guarde en tablas:

-- movies_final_df.write.mode("overwrite").format("parquet").saveAsTable("movie_silver.movies")
