# %% [markdown]
# ### Eliminar y volver a crear todas las Bases de datos

# %%
# %sql
DROP DATABASE IF EXISTS movie_silver CASCADE;

# %% [markdown]
# elimina la DB y las tablas que contiene. Para esto sirve el cascade

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS movie_silver
MANAGED LOCATION "abfss://silver@moviehistory22.dfs.core.windows.net/"

# %%
# %sql
DROP DATABASE IF EXISTS movie_gold CASCADE;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS movie_gold
MANAGED LOCATION "abfss://gold@moviehistory22.dfs.core.windows.net/"
