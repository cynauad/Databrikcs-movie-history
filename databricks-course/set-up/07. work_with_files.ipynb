# %% [markdown]
# ### Trabajar con Archivos (estilo URI y POSIX)
#
# 1. Mostrar los directorios del directorio raiz DBFS
# 2. Mostrar el contenido de un directorio dentro del directorio raiz DBFS
# 3. Mostrar el contenido del Sistema de Archivos Local
# 4. Interactuar con el "Explorador de Archivos DBSF"
# 5. Leer Datos de ADLS mediante el estilo URI

# %% [markdown]
# ### Punto 1

# %% [markdown]
# #### consulta estilo URI para listar el contenido del directorio

# %%
# %fs
ls dbfs:/

# %% [markdown]
# #### mostrar con estilo posix

# %%
dbutils.fs.ls("/")

# %% [markdown]
# ### Punto 2

# %%
#### estilo URI

# %%
# %fs
ls  dbfs:/databricks-datasets/

# %% [markdown]
# #### estilo posix

# %%
dbutils.fs.ls("/databricks-datasets")

# %% [markdown]
# ### Punto 3

# %%
# %fs
ls file:/

# %% [markdown]
# ### Punto 4

# %%
dbutils.fs.ls("/FileStore")

# %% [markdown]
# ### Punto 5

# %%
dbutils.fs.ls("abfss://demo@moviehistory22.dfs.core.windows.net/")
