# %% [markdown]
# ## Explorar las capacidades de la utilidad "dbutils.secrets"

# %%
dbutils.secrets.help()

# %%
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list(scope = "movie-history-secret-sope")

# %%
dbutils.secrets.get(scope = "movie-history-secret-sope", key = "movie-access-key")

# %% [markdown]
# Devuelve "redactado", es decir esta escondido y no se muestra como texto plano. Asi no corremos el riesgo de filtrar la key en algun repo.
