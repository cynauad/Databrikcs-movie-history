# %%
dbutils.fs.ls("abfss://demo@moviehistory22.dfs.core.windows.net/")
# muestra lo que se encuentre dentro del contenedor
# no es necesario especificar la ubicacion external o el storage credencial --- lo hace unity catalog
